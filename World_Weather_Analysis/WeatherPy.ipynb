# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0959b0f0d560eedfc9937e14e532123d

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 578

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#city_data_df = pd.DataFrame(city_data)
#city_data_df.head(10)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("----")
print(url)
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city#.replace(" ","+"

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as E:
        print("City not found. Skipping...")
        print (E)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0959b0f0d560eedfc9937e14e532123d
# Processing Record 1 of Set 1 | jinchang
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | hofn
# Processing Record 4 of Set 1 | sao felix do xingu
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | tawnat
# City not found. Skipping...
# 'coord'
# Processing Record 8 of Set 1 | lagunas
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | maracas
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | tawkar
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | ketchikan
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | racine
# Processing Record 21 of Set 1 | beloha
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | fort nelson
# Processing Record 25 of Set 1 | quibor
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | walvis bay
# Processing Record 33 of Set 1 | san quintin
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | tartagal
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | mombetsu
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | manokwari
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | yulara
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 2 | marzuq
# Processing Record 7 of Set 2 | yerbogachen
# Processing Record 8 of Set 2 | muros
# Processing Record 9 of Set 2 | karaul
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 2 | alpena
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | meulaboh
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | visnes
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | vostok
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | cortes
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | cornwall
# Processing Record 26 of Set 2 | del rio
# Processing Record 27 of Set 2 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | punta alta
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | vuktyl
# Processing Record 33 of Set 2 | north bend
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | itarema
# Processing Record 36 of Set 2 | innisfail
# Processing Record 37 of Set 2 | babanusah
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 2 | burica
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 2 | camacha
# Processing Record 42 of Set 2 | gravdal
# Processing Record 43 of Set 2 | aklavik
# Processing Record 44 of Set 2 | bucerias
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 2 | ensley
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | bushehr
# Processing Record 50 of Set 2 | bonthe
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 3 | shingu
# Processing Record 4 of Set 3 | chimbote
# Processing Record 5 of Set 3 | quesada
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | wasilla
# Processing Record 8 of Set 3 | antofagasta
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | hobbs
# Processing Record 11 of Set 3 | uk
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 3 | mazamari
# Processing Record 14 of Set 3 | tura
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 3 | mao
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | woodward
# Processing Record 20 of Set 3 | miranda
# Processing Record 21 of Set 3 | ninotsminda
# Processing Record 22 of Set 3 | ahipara
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | codrington
# Processing Record 29 of Set 3 | merauke
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 3 | fairmont
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | ardalstangen
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | ambilobe
# Processing Record 37 of Set 3 | dzhusaly
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 3 | bakel
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | akhaldaba
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | tiarei
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | la ronge
# Processing Record 45 of Set 3 | urucui
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | severodvinsk
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | labutta
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | pauini
# Processing Record 5 of Set 4 | voh
# Processing Record 6 of Set 4 | mayo
# Processing Record 7 of Set 4 | mitsamiouli
# Processing Record 8 of Set 4 | rawson
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | bubaque
# Processing Record 12 of Set 4 | qabis
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | breytovo
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | vikhorevka
# Processing Record 17 of Set 4 | karpathos
# Processing Record 18 of Set 4 | ankang
# Processing Record 19 of Set 4 | shawville
# Processing Record 20 of Set 4 | chumikan
# Processing Record 21 of Set 4 | vila franca do campo
# Processing Record 22 of Set 4 | zharkent
# Processing Record 23 of Set 4 | katherine
# Processing Record 24 of Set 4 | algiers
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | san juan
# Processing Record 27 of Set 4 | nishihara
# Processing Record 28 of Set 4 | pemberton
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 | januaria
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | urengoy
# Processing Record 33 of Set 4 | farafangana
# Processing Record 34 of Set 4 | pervomayskoye
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | ambodifototra
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 4 | astana
# Processing Record 38 of Set 4 | nuuk
# Processing Record 39 of Set 4 | qasigiannguit
# Processing Record 40 of Set 4 | slantsy
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | morant bay
# Processing Record 44 of Set 4 | uryupinsk
# Processing Record 45 of Set 4 | pietermaritzburg
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | turkmenabat
# Processing Record 49 of Set 4 | daru
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | nha trang
# Processing Record 2 of Set 5 | tulun
# Processing Record 3 of Set 5 | gaillac
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | maniitsoq
# Processing Record 7 of Set 5 | coahuayana
# Processing Record 8 of Set 5 | port alfred
# Processing Record 9 of Set 5 | chagda
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 5 | port blair
# Processing Record 11 of Set 5 | mujiayingzi
# Processing Record 12 of Set 5 | nampula
# Processing Record 13 of Set 5 | bilibino
# Processing Record 14 of Set 5 | lake city
# Processing Record 15 of Set 5 | soria
# Processing Record 16 of Set 5 | andenes
# Processing Record 17 of Set 5 | rungata
# City not found. Skipping...
# 'coord'
# Processing Record 18 of Set 5 | cap-aux-meules
# Processing Record 19 of Set 5 | ginir
# Processing Record 20 of Set 5 | mpika
# Processing Record 21 of Set 5 | padang
# Processing Record 22 of Set 5 | kununurra
# Processing Record 23 of Set 5 | sinnai
# Processing Record 24 of Set 5 | odesa
# Processing Record 25 of Set 5 | safwah
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | ruidoso
# Processing Record 28 of Set 5 | vao
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 30 of Set 5 | evensk
# Processing Record 31 of Set 5 | sept-iles
# Processing Record 32 of Set 5 | bowen
# Processing Record 33 of Set 5 | tari
# Processing Record 34 of Set 5 | rio grande
# Processing Record 35 of Set 5 | tome-acu
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 5 | calama
# Processing Record 37 of Set 5 | floresta
# Processing Record 38 of Set 5 | antsohihy
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | ca mau
# Processing Record 41 of Set 5 | jinka
# Processing Record 42 of Set 5 | luanda
# Processing Record 43 of Set 5 | alexandria
# Processing Record 44 of Set 5 | sasovo
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | akniste
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | egvekinot
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | guataqui
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | arman
# Processing Record 3 of Set 6 | seymchan
# Processing Record 4 of Set 6 | coihaique
# Processing Record 5 of Set 6 | saint-augustin
# Processing Record 6 of Set 6 | emerald
# Processing Record 7 of Set 6 | ambon
# Processing Record 8 of Set 6 | mancio lima
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | itapua poty
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | saskylakh
# Processing Record 14 of Set 6 | villa guerrero
# Processing Record 15 of Set 6 | balkhash
# Processing Record 16 of Set 6 | biak
# Processing Record 17 of Set 6 | camana
# Processing Record 18 of Set 6 | waddan
# Processing Record 19 of Set 6 | alvorada
# Processing Record 20 of Set 6 | perth
# Processing Record 21 of Set 6 | luganville
# Processing Record 22 of Set 6 | juneau
# Processing Record 23 of Set 6 | araguatins
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 6 | ixtapa
# Processing Record 25 of Set 6 | sobolevo
# Processing Record 26 of Set 6 | ust-nera
# Processing Record 27 of Set 6 | devyatka
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 6 | olafsvik
# Processing Record 29 of Set 6 | beringovskiy
# Processing Record 30 of Set 6 | kingstown
# Processing Record 31 of Set 6 | chistoye
# Processing Record 32 of Set 6 | rudbar
# Processing Record 33 of Set 6 | marsh harbour
# Processing Record 34 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | santa lucia
# Processing Record 37 of Set 6 | batagay
# Processing Record 38 of Set 6 | kaniama
# Processing Record 39 of Set 6 | visalia
# Processing Record 40 of Set 6 | shelburne
# Processing Record 41 of Set 6 | mezibori
# Processing Record 42 of Set 6 | priyutnoye
# Processing Record 43 of Set 6 | rolla
# Processing Record 44 of Set 6 | barinas
# Processing Record 45 of Set 6 | lafiagi
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | sawang daen din
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | verkhoyansk
# Processing Record 50 of Set 6 | grindavik
# Processing Record 1 of Set 7 | jiaojiang
# Processing Record 2 of Set 7 | naryan-mar
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | rantepao
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | sohagpur
# Processing Record 7 of Set 7 | palmer
# Processing Record 8 of Set 7 | kabinda
# Processing Record 9 of Set 7 | cuamba
# Processing Record 10 of Set 7 | tual
# Processing Record 11 of Set 7 | yar-sale
# Processing Record 12 of Set 7 | miri
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | amapa
# Processing Record 15 of Set 7 | benemerito de las americas
# Processing Record 16 of Set 7 | toktogul
# Processing Record 17 of Set 7 | bolshegrivskoye
# City not found. Skipping...
# 'coord'
# Processing Record 18 of Set 7 | port macquarie
# Processing Record 19 of Set 7 | nome
# Processing Record 20 of Set 7 | emirdag
# Processing Record 21 of Set 7 | beeskow
# Processing Record 22 of Set 7 | redwater
# Processing Record 23 of Set 7 | santa cruz
# Processing Record 24 of Set 7 | sattahip
# Processing Record 25 of Set 7 | jensen beach
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | gudari
# Processing Record 28 of Set 7 | hohhot
# Processing Record 29 of Set 7 | asau
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 7 | tambovka
# Processing Record 32 of Set 7 | acajutla
# Processing Record 33 of Set 7 | mazatlan
# Processing Record 34 of Set 7 | kopyevo
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 7 | itaituba
# Processing Record 36 of Set 7 | lorengau
# Processing Record 37 of Set 7 | liku
# Processing Record 38 of Set 7 | rosamorada
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | bambous virieux
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | xinmin
# Processing Record 43 of Set 7 | sokyryany
# Processing Record 44 of Set 7 | orange
# Processing Record 45 of Set 7 | naica
# Processing Record 46 of Set 7 | acari
# Processing Record 47 of Set 7 | lexington
# Processing Record 48 of Set 7 | chute-aux-outardes
# Processing Record 49 of Set 7 | chapais
# Processing Record 50 of Set 7 | kaltasy
# Processing Record 1 of Set 8 | te anau
# Processing Record 2 of Set 8 | narsaq
# Processing Record 3 of Set 8 | dingle
# Processing Record 4 of Set 8 | kayes
# Processing Record 5 of Set 8 | nara
# Processing Record 6 of Set 8 | avera
# Processing Record 7 of Set 8 | karamea
# City not found. Skipping...
# 'coord'
# Processing Record 8 of Set 8 | balakhninskiy
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 8 | hammerfest
# Processing Record 12 of Set 8 | banda aceh
# Processing Record 13 of Set 8 | limbang
# Processing Record 14 of Set 8 | kemin
# Processing Record 15 of Set 8 | malwan
# City not found. Skipping...
# 'coord'
# Processing Record 16 of Set 8 | williston
# Processing Record 17 of Set 8 | lakes entrance
# Processing Record 18 of Set 8 | blagoveshchensk
# Processing Record 19 of Set 8 | uspenka
# Processing Record 20 of Set 8 | ust-ishim
# Processing Record 21 of Set 8 | comodoro rivadavia
# Processing Record 22 of Set 8 | rebrikha
# Processing Record 23 of Set 8 | hasaki
# Processing Record 24 of Set 8 | ormara
# Processing Record 25 of Set 8 | acurenam
# Processing Record 26 of Set 8 | bur gabo
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 8 | russell
# Processing Record 28 of Set 8 | ascension
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | rundu
# Processing Record 31 of Set 8 | port-cartier
# Processing Record 32 of Set 8 | palu
# Processing Record 33 of Set 8 | heihe
# Processing Record 34 of Set 8 | swan hill
# Processing Record 35 of Set 8 | chantada
# Processing Record 36 of Set 8 | jalu
# Processing Record 37 of Set 8 | ukiah
# Processing Record 38 of Set 8 | boyolangu
# Processing Record 39 of Set 8 | flin flon
# Processing Record 40 of Set 8 | hamilton
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | aswan
# Processing Record 43 of Set 8 | aksu
# Processing Record 44 of Set 8 | westport
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | omboue
# Processing Record 47 of Set 8 | bar-le-duc
# Processing Record 48 of Set 8 | minsk
# Processing Record 49 of Set 8 | fleetwood
# Processing Record 50 of Set 8 | athabasca
# Processing Record 1 of Set 9 | ayan
# Processing Record 2 of Set 9 | japura
# Processing Record 3 of Set 9 | fairbanks
# Processing Record 4 of Set 9 | agirish
# Processing Record 5 of Set 9 | grand centre
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 9 | porto santo
# Processing Record 7 of Set 9 | ondjiva
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | havoysund
# Processing Record 10 of Set 9 | menongue
# Processing Record 11 of Set 9 | devils lake
# Processing Record 12 of Set 9 | hambantota
# Processing Record 13 of Set 9 | zurrieq
# Processing Record 14 of Set 9 | kendal
# Processing Record 15 of Set 9 | xuddur
# Processing Record 16 of Set 9 | champerico
# Processing Record 17 of Set 9 | palana
# Processing Record 18 of Set 9 | lac du bonnet
# Processing Record 19 of Set 9 | kuala terengganu
# Processing Record 20 of Set 9 | taltal
# Processing Record 21 of Set 9 | utiroa
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | bohl-iggelheim
# Processing Record 24 of Set 9 | krasnogorsk
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 9 | waingapu
# Processing Record 27 of Set 9 | tuggurt
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 9 | caceres
# Processing Record 29 of Set 9 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 30 of Set 9 | torata
# Processing Record 31 of Set 9 | adrar
# Processing Record 32 of Set 9 | salalah
# Processing Record 33 of Set 9 | nelson bay
# Processing Record 34 of Set 9 | sarangani
# Processing Record 35 of Set 9 | loa janan
# Processing Record 36 of Set 9 | cap malheureux
# Processing Record 37 of Set 9 | lumphat
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | neyshabur
# Processing Record 40 of Set 9 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 9 | sabha
# Processing Record 42 of Set 9 | manaus
# Processing Record 43 of Set 9 | pacific grove
# Processing Record 44 of Set 9 | nantucket
# Processing Record 45 of Set 9 | vredendal
# Processing Record 46 of Set 9 | labuhan
# Processing Record 47 of Set 9 | morro bay
# Processing Record 48 of Set 9 | kodinsk
# Processing Record 49 of Set 9 | vardo
# Processing Record 50 of Set 9 | troitsko-pechorsk
# Processing Record 1 of Set 10 | dolbeau
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 10 | garowe
# Processing Record 3 of Set 10 | buchanan
# Processing Record 4 of Set 10 | whitehorse
# Processing Record 5 of Set 10 | mangrol
# Processing Record 6 of Set 10 | fort dodge
# Processing Record 7 of Set 10 | pravda
# Processing Record 8 of Set 10 | saint simons
# Processing Record 9 of Set 10 | togur
# Processing Record 10 of Set 10 | awbari
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | coquimbo
# Processing Record 13 of Set 10 | luan
# Processing Record 14 of Set 10 | chatellerault
# Processing Record 15 of Set 10 | inuvik
# Processing Record 16 of Set 10 | vanimo
# Processing Record 17 of Set 10 | beni suef
# Processing Record 18 of Set 10 | kibala
# Processing Record 19 of Set 10 | kiama
# Processing Record 20 of Set 10 | liverpool
# Processing Record 21 of Set 10 | pskov
# Processing Record 22 of Set 10 | wajir
# Processing Record 23 of Set 10 | rongcheng
# Processing Record 24 of Set 10 | mae hong son
# Processing Record 25 of Set 10 | solnechnyy
# Processing Record 26 of Set 10 | pimentel
# Processing Record 27 of Set 10 | tabiauea
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 10 | opuwo
# Processing Record 29 of Set 10 | rocha
# Processing Record 30 of Set 10 | taoudenni
# Processing Record 31 of Set 10 | xichang
# Processing Record 32 of Set 10 | afanasyevo
# City not found. Skipping...
# 'coord'
# Processing Record 33 of Set 10 | bendigo
# Processing Record 34 of Set 10 | don sak
# Processing Record 35 of Set 10 | teya
# Processing Record 36 of Set 10 | leshukonskoye
# Processing Record 37 of Set 10 | talakan
# Processing Record 38 of Set 10 | kribi
# Processing Record 39 of Set 10 | thinadhoo
# Processing Record 40 of Set 10 | zhigansk
# Processing Record 41 of Set 10 | ostrovnoy
# Processing Record 42 of Set 10 | phalombe
# Processing Record 43 of Set 10 | lastoursville
# Processing Record 44 of Set 10 | saint-georges
# Processing Record 45 of Set 10 | elizabeth city
# Processing Record 46 of Set 10 | usogorsk
# Processing Record 47 of Set 10 | wajima
# Processing Record 48 of Set 10 | haradok
# Processing Record 49 of Set 10 | yamada
# Processing Record 50 of Set 10 | blagoveshchenka
# Processing Record 1 of Set 11 | razole
# Processing Record 2 of Set 11 | kushmurun
# Processing Record 3 of Set 11 | hauterive
# Processing Record 4 of Set 11 | oistins
# Processing Record 5 of Set 11 | gisborne
# Processing Record 6 of Set 11 | tottori
# Processing Record 7 of Set 11 | north kessock
# Processing Record 8 of Set 11 | raudeberg
# Processing Record 9 of Set 11 | pucallpa
# Processing Record 10 of Set 11 | waipawa
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | port lincoln
# Processing Record 13 of Set 11 | moses lake
# Processing Record 14 of Set 11 | usinsk
# Processing Record 15 of Set 11 | hvammstangi
# City not found. Skipping...
# 'coord'
# Processing Record 16 of Set 11 | silvia
# Processing Record 17 of Set 11 | lodi
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | high level
# Processing Record 20 of Set 11 | baruun-urt
# Processing Record 21 of Set 11 | diamantino
# Processing Record 22 of Set 11 | los llanos de aridane
# Processing Record 23 of Set 11 | minab
# Processing Record 24 of Set 11 | panguna
# Processing Record 25 of Set 11 | ust-kulom
# Processing Record 26 of Set 11 | pozo colorado
# Processing Record 27 of Set 11 | tacuarembo
# Processing Record 28 of Set 11 | jawhar
# Processing Record 29 of Set 11 | umm lajj
# Processing Record 30 of Set 11 | husavik
# Processing Record 31 of Set 11 | tolaga bay
# Processing Record 32 of Set 11 | pathein
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | bandrele
# Processing Record 35 of Set 11 | lundamo
# Processing Record 36 of Set 11 | sfantu gheorghe
# Processing Record 37 of Set 11 | tommot
# Processing Record 38 of Set 11 | manmad
# Processing Record 39 of Set 11 | balezino
# Processing Record 40 of Set 11 | cairns
# Processing Record 41 of Set 11 | todos santos
# Processing Record 42 of Set 11 | kaeo
# Processing Record 43 of Set 11 | kamojima
# Processing Record 44 of Set 11 | magomeni
# Processing Record 45 of Set 11 | port moresby
# Processing Record 46 of Set 11 | kieta
# Processing Record 47 of Set 11 | hami
# Processing Record 48 of Set 11 | boone
# Processing Record 49 of Set 11 | porto belo
# Processing Record 50 of Set 11 | grand-santi
# Processing Record 1 of Set 12 | homa bay
# Processing Record 2 of Set 12 | jaque
# Processing Record 3 of Set 12 | kokopo
# Processing Record 4 of Set 12 | california city
# Processing Record 5 of Set 12 | bolgatanga
# Processing Record 6 of Set 12 | rudnogorsk
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | saint-joseph
# Processing Record 9 of Set 12 | concordia
# Processing Record 10 of Set 12 | klyuchi
# Processing Record 11 of Set 12 | lolua
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 12 | ulladulla
# Processing Record 13 of Set 12 | alice springs
# Processing Record 14 of Set 12 | vigeland
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | makakilo city
# Processing Record 17 of Set 12 | takoradi
# Processing Record 18 of Set 12 | xining
# Processing Record 19 of Set 12 | tokmak
# Processing Record 20 of Set 12 | barra
# Processing Record 21 of Set 12 | esik
# Processing Record 22 of Set 12 | horadiz
# Processing Record 23 of Set 12 | geraldton
# Processing Record 24 of Set 12 | san patricio
# Processing Record 25 of Set 12 | quelimane
# Processing Record 26 of Set 12 | sorvag
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 12 | gimli
# Processing Record 28 of Set 12 | porto de moz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Jinchang  38.4953  102.1739     49.82        20         100
# 1         Tuktoyaktuk  69.4541 -133.0374    -21.95        99          99
# 2                Hofn  64.2539  -15.2082     36.68        60         100
# 3  Sao Felix Do Xingu  -6.6447  -51.9950     75.45        91         100
# 4               Vaini -21.2000 -175.2000     77.00        94          75
# 5        Punta Arenas -53.1500  -70.9167     44.60        57          20
# 6             Lagunas  -5.2269  -75.6753     73.49        98         100
# 7            Saldanha -33.0117   17.9442     84.20        32         100
# 8         Yellowknife  62.4560 -114.3525     12.20        62          75
# 9             Maracas -13.4411  -40.4308     82.29        30           1
#
#    Wind Speed Country                 Date
# 0        9.82      CN  2021-03-28 12:42:15
# 1        8.77      CA  2021-03-28 12:42:15
# 2       27.45      IS  2021-03-28 12:42:16
# 3        0.65      BR  2021-03-28 12:42:16
# 4        5.75      TO  2021-03-28 12:42:16
# 5       24.16      CL  2021-03-28 12:40:39
# 6        1.81      PE  2021-03-28 12:42:16
# 7        8.05      ZA  2021-03-28 12:42:17
# 8       11.50      CA  2021-03-28 12:42:17
# 9        3.09      BR  2021-03-28 12:42:17

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
